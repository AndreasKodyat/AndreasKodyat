# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreasKodyat/AndreasKodyat/blob/main/POS_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name? ")
print("Hello, "+ name + ".")

# %% [markdown]
# Sample print and input usage

# %%
print("Menu")
print("1. Fried chicken.")
print("2. French fries.")
print("3. Chicken Burger.")
print("4. Classic Beef Burger.")
print("5. Coke.")
print("6. 7-Up.")

# ask for user selection
selection = input("Which menu you want to order? ")
print("You select menu number " + selection)
# Out:
# Menu
# 1. Fried chicken.
# 2. French fries.
# 3. Chicken Burger.
# 4. Classic Beef Burger.
# 5. Coke.
# 6. 7-Up.
# Which menu you want to order? 3
# You select menu number 3

# %% [markdown]
# Sample menu display, ask for selection from user. Then print out the menu number selected.
